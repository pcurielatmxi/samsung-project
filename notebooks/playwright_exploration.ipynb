# %% [markdown]
# # Interactive Playwright Exploration
#
# This notebook lets you explore ProjectSight interactively with Playwright.
#
# **Tips:**
# - Run cells one at a time
# - The browser will open in a visible window (headless=False)
# - Use `page.pause()` to open Playwright Inspector for picking locators
# - Session is saved automatically after login for reuse

# %%
# Setup - run this first
from playwright.async_api import async_playwright
from pathlib import Path
import asyncio
from dotenv import load_dotenv
import os

load_dotenv(r'/home/pdcur/samsung-project/.env')

USERNAME = os.getenv('PROJECTSIGHT_USERNAME_2')
PASSWORD = os.getenv('PROJECTSIGHT_PASSWORD_2')

print(f"Using username: {USERNAME}")
# Out:
# Using username: pcuriel@mxi.pro

# %%
# Session storage path
storage_path = Path.home() / ".projectsight_session.json"

# Target URL
TARGET_URL = "https://prod.projectsightapp.trimble.com/web/app/Project?listid=-4045&orgid=4540f425-f7b5-4ad8-837d-c270d5d09490&projid=3"

# Store playwright instance globally
pw = None
browser = None
context = None
page = None

print(f"Session file: {storage_path}")
print(f"Session exists: {storage_path.exists()}")
# Out:
# Session file: /home/pdcur/.projectsight_session.json
# Session exists: True

# %%
# Launch browser with saved session (if available)
pw = await async_playwright().start()
browser = await pw.chromium.launch(headless=False)

# Load saved session if it exists
context_options = {"viewport": {"width": 1920, "height": 1080}}
if storage_path.exists():
    context_options["storage_state"] = str(storage_path)
    print("Loading saved session...")
else:
    print("No saved session, will need to login")

context = await browser.new_context(**context_options)
page = await context.new_page()
print("Browser launched!")
# Out:
# Loading saved session...
# Browser launched!

# %%
# Navigate to target page
await page.goto(TARGET_URL, wait_until="domcontentloaded")
await page.wait_for_timeout(3000)  # Give it a moment to redirect if needed

print(f"Current URL: {page.url}")

# Check if we need to login
needs_login = "id.trimble.com" in page.url or "sign_in" in page.url

if needs_login:
    print(">>> Login required - run the login cells below")
    
    try:
        await page.get_by_role("button", name="Reject All").click(timeout=3000)
        print("Dismissed cookie modal")
    except:
        print("No cookie modal appeared")
        
    # Login Step 1: Enter username
    await page.fill('#username-field', USERNAME)
    # The Next button may be disabled until field is blurred, so we simulate a Tab key press
    await page.keyboard.press('Tab') 
    await page.get_by_role("button", name="Next").click()
    print("Username entered, clicked Next")

    # Wait for password field
    await page.wait_for_selector('input[name="password"]', timeout=5000)
    print("Password field appeared")
    
    # Login Step 2: Enter password and submit
    await page.fill('input[name="password"]', PASSWORD)
    # The Sign in button may be disabled until field is blurred, so we simulate a Tab key press
    await page.keyboard.press('Tab') 
    await page.get_by_role("button", name="Sign in").click()
    print("Password entered, logging in...")

    # Wait for redirect to ProjectSight
    await page.wait_for_url('**projectsight**', timeout=10000)
    print(f"Logged in! URL: {page.url}")

    # Save session for next time
    await context.storage_state(path=str(storage_path))
    print(f"Session saved to {storage_path}")
        
else:
    print(">>> Already authenticated! Skip to the exploration cells")
# Out:
# Current URL: https://prod.projectsightapp.trimble.com/web/app/Project?listid=-4045&orgid=4540f425-f7b5-4ad8-837d-c270d5d09490&projid=3
# >>> Already authenticated! Skip to the exploration cells

# %% [markdown]
# ## Exploration
#
# Now you're logged in! Use these cells to explore.

# %%
await page.pause()

# %%
# Get the iframe and then the filter input                                                           
frame = page.locator("iframe[name=\"fraMenuContent\"]").content_frame                                
spec_section_input = frame.locator("#ucSearchPanel_ctl38_txtCSICodeLookupInput") 

# 1. Click to open the dropdown 
await spec_section_input.click(timeout=2000)

# 2. Type to filter the list                                                                         
await frame.locator("#ucSearchPanel_ctl38_txtCSICodeLookupInput").click(timeout=2000)

try:
    # Click on the Metal division expand button if not expanded yet
    await frame.locator("#ucSearchPanel_ctl38_CSICodePopupTreeContainer_73003").get_by_title("Expand Row").click(timeout=2000)
except:
    print("Row already expanded")
await frame.get_by_role("gridcell", name="05 12 00 - Structural Steel").click(timeout=2000) 
# await frame.locator("#ucSearchPanel_ctl38_txtCSICodeLookupInput").type("05 12 00", timeout=5000)
#  

page.wait_for_timeout(5000) # Wait to see the selection
await frame.locator("#imgSwitchToListView").click(timeout=2000)  # Switch to list view for easier parsing
print("Switched to list view")
# Out:
# Row already expanded

# %%
# Find the scrollable table container                                                                
scroll_container = frame.locator(".ui-iggrid-scrolldiv-y, .ui-iggrid-virtualization-container, [class*='scroll']").first
print(scroll_container)
# Out:
# <Locator frame=<Frame name= url='https://prod.projectsightapp.trimble.com/web/app/Project?listid=-4045&orgid=4540f425-f7b5-4ad8-837d-c270d5d09490&projid=3'> selector='iframe[name="fraMenuContent"] >> internal:control=enter-frame >> .ui-iggrid-scrolldiv-y, .ui-iggrid-virtualization-container, [class*=\'scroll\'] >> nth=0'>

# %%
processed = 0                                                                                        
seen_texts = set()  # Track unique rows to avoid duplicates 

while True: 
    rows = frame.locator("tbody tr")
    count = await rows.count()
    
    # Proces new rows:
    for i in range(processed, count):
        row = rows.nth(i)
        text = await row.inner_text()

        # Skip if already seen (virtual scrolling can re-render)                                     
        if text in seen_texts:                                                                       
            continue     
                                                                                    
        seen_texts.add(text)
        print(f"Row {i+1}: {text.replace(chr(10), ' | ')}")  # Replace newlines for better readability
        
    processed = count
    
    # Scroll to the last row to trigger loading more rows
    await rows.last.scroll_into_view_if_needed()
    await frame.wait_for_timeout(2000)  # Wait for new rows to load
    
    # Check if more rows were loaded
    new_count = await rows.count()
    if new_count == count:
        print("No more new rows to load.")
        break
    
print("Finished processing all rows.")
print(f"Total unique rows processed: {len(seen_texts)}")
# Out:
# Row 1:  |                  |                     My views |                  |                  | 					 |                      |                      |                  |
# Row 2: 	 | Number | 	 | Revision	 | Spec section	 | Spec sub section	 | Subject	 | Status	 | Due date	 | Open assignments	 |
# Row 3: 	 | Number | 	 | Revision	 | Spec section	 | Spec sub section	 | Subject	 | Status	 | Due date	 | Open assignments
# Row 4: 	0317	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0841_061 - 05 12 00 - 0 - TRS - Structural Steel - Trestle A, B, E, F, & M Anchor Bolt - SD	 Approved with Comments	4/25/2023		 |  | 	0356	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0855_062 - 05 12 00 - 0 - GCS - Structural Steel - Shell Steel - GL 1-11 - SD	 Approved with Comments	5/1/2023		 |  | 	0357	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0856_063 - 05 12 00 - 0 - GCS - Structural Steel - Shell Steel - GL 11-20 - SD	 Approved with Comments	5/1/2023		 |  | 	0373	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0077 - Structural Steel Shop Drawing Engineering Calculations	 Approved with Comments	4/25/2023		 |  | 	0380	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0079 - CTIW-RECAL Welder Qualifications	 Approved	4/25/2023		 |  | 	0406	1	05 12 00 - Structural Steel Framing		[138kV] PSC-SEAC-CSA-MAR - 0169 - NON-Shrink Grout	 Approved	6/10/2023		 |  | 	0427	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0875_[Y_SBMT#0260] Girts at GL C-D and GL 10-20 - Shop Drawings	 Approved with Comments	5/5/2023		 |  | 	0428	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0882_[Y_SBMT#0261] Girts at GL K-L and GL 10-20 - Shop Drawings	 Approved with Comments	5/5/2023		 |  | 	0429	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0884_064 - 05 12 00 - 0 - GCS - Structural Steel - Shell Steel - GL 30-40 - SD	 Approved with Comments	5/5/2023		 |  | 	0434	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0087 - Module 41-M-2D Structural Steel Shop Drawings	 Approved with Comments	5/1/2023		 |  | 	0436	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0088 - Module 42-M-9A Steel Shop Drawings	 Approved with Comments	5/1/2023		 |  | 	0438	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0089 - Module 43-M-9B Structural Steel Shop Drawings	 Approved with Comments	5/1/2023		 |  | 	0447	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0891_OFA - Skylight Steel Tubes Calculations - SDI - SD	 Received for Information. Not Subject to Review	5/4/2023		 |  | 	0447	1	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0891_OFA - Skylight Steel Tubes Calculations - SDI - SD Rev.1	 Received for Information. Not Subject to Review	9/26/2023		 |  | 	0461	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0094 - Module 01-M-1A Structural Steel Shop Drawings	 Approved with Comments	5/8/2023		 |  | 	0462	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0095 - Module 02-M-1B Structural Steel Shop Drawings	 Approved with Comments	5/4/2023		 |  | 	0464	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0096 - Module 03-M-1C Structural Steel Shop Drawings	 Approved with Comments	5/5/2023		 |  | 	0467	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0887_OFA - Skylight Steel Tubes - SDI - SD	 Approved with Comments	5/9/2023		 |  | 	0497	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0909_066 - 05 12 00 - 0 - GCS - Structural Steel - Shell Steel - GL 49-62 - SD	 Approved with Comments	5/12/2023		 |  | 	0505	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0062 - Structural Steel Engineering Calculations	 Approved with Comments	5/9/2023		 |  | 	0638	1	05 12 00 - Structural Steel Framing		[STS] PSC-SEAC-CSA-MAR-0180 - Trestle R Crossover Bridge REVISED	 Approved with Comments	5/20/2023		 |  | 	0655	0	05 12 00 - Structural Steel Framing		[138kV] MAR for Firewall anchor bolts	 Approved	5/21/2023		 |  | 	0684	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0995_Connection Design Package #25	 Approved with Comments	5/30/2023		 |  | 	0685	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0996_SUW - GL K-N30-33 Level 2 & 04A - Seq 9404 & 9405 EOS	 Approved with Comments	5/30/2023		 |  | 	0718	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1026_Decking Lvl 4-6 @ SUE & SUW	 Approved with Comments	6/2/2023		 |  | 	0740	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1032_Seq. 7101	 Approved with Comments	6/4/2023		 |  | 	0762	0	 ...
# Row 5: 	0317	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0841_061 - 05 12 00 - 0 - TRS - Structural Steel - Trestle A, B, E, F, & M Anchor Bolt - SD	 Approved with Comments	4/25/2023
# Row 6: 	0356	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0855_062 - 05 12 00 - 0 - GCS - Structural Steel - Shell Steel - GL 1-11 - SD	 Approved with Comments	5/1/2023
# Row 7: 	0357	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0856_063 - 05 12 00 - 0 - GCS - Structural Steel - Shell Steel - GL 11-20 - SD	 Approved with Comments	5/1/2023
# Row 8: 	0373	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0077 - Structural Steel Shop Drawing Engineering Calculations	 Approved with Comments	4/25/2023
# Row 9: 	0380	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0079 - CTIW-RECAL Welder Qualifications	 Approved	4/25/2023
# Row 10: 	0406	1	05 12 00 - Structural Steel Framing		[138kV] PSC-SEAC-CSA-MAR - 0169 - NON-Shrink Grout	 Approved	6/10/2023
# Row 11: 	0427	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0875_[Y_SBMT#0260] Girts at GL C-D and GL 10-20 - Shop Drawings	 Approved with Comments	5/5/2023
# Row 12: 	0428	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0882_[Y_SBMT#0261] Girts at GL K-L and GL 10-20 - Shop Drawings	 Approved with Comments	5/5/2023
# Row 13: 	0429	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0884_064 - 05 12 00 - 0 - GCS - Structural Steel - Shell Steel - GL 30-40 - SD	 Approved with Comments	5/5/2023
# Row 14: 	0434	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0087 - Module 41-M-2D Structural Steel Shop Drawings	 Approved with Comments	5/1/2023
# Row 15: 	0436	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0088 - Module 42-M-9A Steel Shop Drawings	 Approved with Comments	5/1/2023
# Row 16: 	0438	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0089 - Module 43-M-9B Structural Steel Shop Drawings	 Approved with Comments	5/1/2023
# Row 17: 	0447	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0891_OFA - Skylight Steel Tubes Calculations - SDI - SD	 Received for Information. Not Subject to Review	5/4/2023
# Row 18: 	0447	1	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0891_OFA - Skylight Steel Tubes Calculations - SDI - SD Rev.1	 Received for Information. Not Subject to Review	9/26/2023
# Row 19: 	0461	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0094 - Module 01-M-1A Structural Steel Shop Drawings	 Approved with Comments	5/8/2023
# Row 20: 	0462	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0095 - Module 02-M-1B Structural Steel Shop Drawings	 Approved with Comments	5/4/2023
# Row 21: 	0464	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0096 - Module 03-M-1C Structural Steel Shop Drawings	 Approved with Comments	5/5/2023
# Row 22: 	0467	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0887_OFA - Skylight Steel Tubes - SDI - SD	 Approved with Comments	5/9/2023
# Row 23: 	0497	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0909_066 - 05 12 00 - 0 - GCS - Structural Steel - Shell Steel - GL 49-62 - SD	 Approved with Comments	5/12/2023
# Row 24: 	0505	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0062 - Structural Steel Engineering Calculations	 Approved with Comments	5/9/2023
# Row 25: 	0638	1	05 12 00 - Structural Steel Framing		[STS] PSC-SEAC-CSA-MAR-0180 - Trestle R Crossover Bridge REVISED	 Approved with Comments	5/20/2023
# Row 26: 	0655	0	05 12 00 - Structural Steel Framing		[138kV] MAR for Firewall anchor bolts	 Approved	5/21/2023
# Row 27: 	0684	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0995_Connection Design Package #25	 Approved with Comments	5/30/2023
# Row 28: 	0685	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0996_SUW - GL K-N30-33 Level 2 & 04A - Seq 9404 & 9405 EOS	 Approved with Comments	5/30/2023
# Row 29: 	0718	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1026_Decking Lvl 4-6 @ SUE & SUW	 Approved with Comments	6/2/2023
# Row 30: 	0740	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1032_Seq. 7101	 Approved with Comments	6/4/2023
# Row 31: 	0762	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1042_Shop Drawings - SUW - GL L-N17-21 - Seq 9301 Re-Approval	 Approved with Comments	6/8/2023
# Row 32: 	0768	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1044_Shop Drawings - Slab Edge @ GL K-L19 & C-D19 - Seq 4620 & 4720	 Approved with Comments	6/8/2023
# Row 33: 	0769	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1045_Shop Drawings - Decking Drawings added in F03B.03	 Approved with Comments	6/8/2023
# Row 34: 	0775	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1058_SUE - AG&E Pipe Rack - Hangers - Seq. 7102	 Approved	6/9/2023
# Row 35: 	0776	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1057_SUE - AG&E Pipe Rack - Hangers - Seq. 8701 & 8702	 Approved with Comments	6/9/2023
# Row 36: 	0777	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1068_SUW - AG&E Pipe Rack - Hangers - Seq. 8703 & 8704	 Approved with Comments	6/6/2023
# Row 37: 	0780	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1043_Shop Drawings - Slab Edge @ DS East & West - Seq 1620 & 1720	 Approved with Comments	6/13/2023
# Row 38: 	0782	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1055_069 - 05 12 00 - 0 - GCS - Coiling Doors Support Steel - Shop drawings	 Approved with Comments	6/13/2023
# Row 39: 	0794	0	05 12 00 - Structural Steel Framing		PSC-SEAC-CSA-MAR-0200 - Single Post T-Frame Low Profile	 Approved	6/9/2023
# Row 40: 	0798	0	05 12 00 - Structural Steel Framing		PSC-SEAC-CSA-MAR-0203 - Structure Adapter	 Approved with Comments	6/10/2023
# Row 41: 	0800	0	05 12 00 - Structural Steel Framing		[STS] PSC-SEAC-CSA-MAR-0204 - Fluorogold Slide Plates	 Approved with Comments	6/10/2023
# Row 42: 	0804	1	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1012_TM012-2 Trestles - PCL first round Shop Drawings - Trestle E, Module M22B Structural Steel	 Approved with Comments	6/29/2023
# Row 43: 	0807	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1084_070 - 05 12 00 - 0 - TRS - Structural Steel - Trestle Over Bridge A & B - SSEP & Erection Drawings	 Received for Information. Not Subject to Review	6/14/2023
# Row 44: 	0895	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1130_Shop Drawings - SUW - Level 3 @ GL 5-6L-M Seq. 9210	 Approved with Comments	6/22/2023
# Row 45: 	0898	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1145_EUV Support - Sequence 7	 Approved with Comments	6/21/2023
# Row 46: 	0909	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1132_Shop Drawings - Seq. 1901 Changes per SECAI-FAB-S-2284 & AFCO RFI 237	 Approved with Comments	6/22/2023
# Row 47: 	0917	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1131_Shop Drawings - SUE - Seq. 1601 Updated E-Sheets	 Approved with Comments	6/23/2023
# Row 48: 	0926	2	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0694_Truss Upper Ceiling Shop Drawings_rev2	 Approved with Comments	7/12/2023
# Row 49: 	0926	3	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0694_Truss Upper Ceiling Shop Drawings_rev3	 Approved with Comments	8/24/2023
# Row 50: 	0926	4	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0694_Truss Upper Ceiling Shop Drawings_rev4	 Approved with Comments	12/22/2023
# Row 51: 	0926	5	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0694_Truss Upper Ceiling Shop Drawings/4F UPPER CEILING PLAN & DETAIL SHOP DWG_rev5	 Approved with Comments	4/11/2024
# Row 52: 	0940	1	05 12 00 - Structural Steel Framing		TF1-SMT-SH-0782-001_Structural Steel - Over Bridges A & B - SD Rev.1	 Approved with Comments	6/26/2023
# Row 53: 	0953	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1173_Trestle D MOD33 B & C PE Stamped Calculation and Shop Drawings	 Approved with Comments	6/27/2023
# Row 54: 	0957	0	05 12 00 - Structural Steel Framing	G09	TF1-SMT-SH-1176_TM012-2 Trestles - PCL Shop Drawings - Trestle F2, Module M10A Structural Steel	 Approved with Comments	6/24/2023
# Row 55: 	0958	0	05 12 00 - Structural Steel Framing	SP3	TF1-SMT-SH-1177_TM012-2 Trestles - PCL Shop Drawings - Trestle E1, Module M23A Structural Steel	 Approved with Comments	6/24/2023
# Row 56: 	0960	0	05 12 00 - Structural Steel Framing	SP3	TF1-SMT-SH-1178_TM012-2 Trestles - PCL Shop Drawings - Trestle E, Module M22D Structural Steel	 Approved with Comments	6/24/2023
# Row 57: 	0962	0	05 12 00 - Structural Steel Framing	C05D	TF1-SMT-SH-1179_TM012-2 Trestles - PCL Shop Drawings - Trestle M, Module M Structural Steel	 Approved with Comments	6/24/2023
# Row 58: 	0974	0	05 12 00 - Structural Steel Framing	SP3	TF1-SMT-SH-1190_TM012-2 Trestles - PCL Shop Drawings - Trestle F1, Module M12B Structural Steel	 Approved with Comments	6/24/2023
# Row 59: 	0975	0	05 12 00 - Structural Steel Framing	SP3	TF1-SMT-SH-1191_TM012-2 Trestles - PCL Shop Drawings - Trestle F1, Module M12A Structural Steel	 Approved with Comments	6/24/2023
# Row 60: 	0986	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1192_TM012-2 Trestles - PCL Shop Drawings - Trestle F1, Module M19C Structural Steel	 Approved with Comments	6/29/2023
# Row 61: 	0987	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1193_TM012-2 Trestles - PCL Shop Drawings - Trestle F1, Module M12C Structural Steel	 Approved with Comments	6/29/2023
# Row 62: 	0991	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1194_TM012-2 Trestles - PCL Shop Drawings - Trestle F1, Module M19B Structural Steel	 Approved with Comments	6/27/2023
# Row 63: 	0992	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1195_TM012-2 Trestles - PCL Shop Drawings - Trestle F1, Module M12C Structural Steel	 Approved with Comments	6/29/2023
# Row 64: 	0995	0	05 12 00 - Structural Steel Framing		[STS] 22.006.SUB.0188- Cable Tray and Pipe Support Unistrut	 Approved with Comments	6/25/2023
# Row 65: 	1009	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1210_TM012-2 Trestles - PCL Shop Drawings - Trestle E, Expansion Loop Structural Steel	 Approved with Comments	6/30/2023
# Row 66: 	1010	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1211_TM012-2 Trestles - PCL Shop Drawings - Trestle F1, Module M11 Structural Steel	 Approved with Comments	6/30/2023
# Row 67: 	1011	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1212_TM012-2 Trestles - PCL Shop Drawings - Trestle E2, Module M21C Structural Steel	 Approved with Comments	6/30/2023
# Row 68: 	1012	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1015_TM012-2 Trestles - PCL Shop Drawings - Trestle F, Expansion Loop Structural Steel	 Approved with Comments	6/30/2023
# Row 69: 	1041	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1240_Trestle A Detail & Erection Shop Drawings	 Not Accepted - Revise and Resubmit	7/4/2023
# Row 70: 	1048	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1101_Shop Drawings - Seq. 9201 Changes per SECAI RFI 2130 & AFCO RFI 237	 Approved with Comments	7/4/2023
# Row 71: 	1051	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1237_071-05 12 00-0 - Structural Steel - CUB - Roof Davits - Shop and Erection Drawings	 Approved	7/5/2023
# Row 72: 	1087	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1126_Shop Drawings - Seq. 1525, 1535, 1545 FIZ Roof Redesign Incorporation	 Approved	7/7/2023
# Row 73: 	1116	0	05 12 00 - Structural Steel Framing		[138kV] [STS] PSC-SEAC-CSA-MAR-0223 - Cable Tray Crossover - E-House to Trestle R	 Approved	7/6/2023
# Row 74: 	1152	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1303_GCS-A_CL11-27_C-D_COMBINED	 Not Accepted - Revise and Resubmit	7/13/2023
# Row 75: 	1176	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1329_Shop Drawings - Seq. 4620 & 4720 - Slab Edge @ GL K-L19 & C-D19	 Approved with Comments	7/14/2023
# Row 76: 	1210	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1348_[Y_SBMT#676] Shop Drawings - Seq. 1605, 1701 & 1803 per SECAI RFI #2351	 Approved	7/20/2023
# Row 77: 	1211	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1351_Shop Drawings - Seq. 4620 & 4720 - Slab Edge @ GL K-L19 & C-D19	 Approved	7/20/2023
# Row 78: 	1212	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1350_Shop Drawings - Seq. 1902 FW per RFI 1659	 Approved with Comments	7/20/2023
# Row 79: 	1213	0	05 12 00 - Structural Steel Framing		TF1-SMT-SH-01349_Shop Drawings - Seq. 1801 FW per RFI 2477	 Approved	7/20/2023
# Row 80: 	1229	1	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1313_Spitzer Shop Drawings: Building A, Column Lines 26-27 & A-C Inside Rev.1	 Not Accepted - Revise and Resubmit	9/4/2023
# Row 81: 	1229	2	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1313_Spitzer Shop Drawings: Building A, Column Lines 26-27 & A-C Inside Rev.2	 Not Accepted - Revise and Resubmit	10/22/2023
# Row 82: 	1315	1	05 12 00 - Structural Steel Framing		TF1-SMT-SH-1398_FIZ - AG&E Pipe Rack - Column Stubs - Seq. 9101 Approval Rev.1	 Approved with Comments	9/12/2023
# Row 83:
# Row 85:  | 		 |                  |              | 		 |                  |              |
# Row 90:  |              |                  |              |              |                  |              |
# Row 91:  |              |                 8 of 40 selected |              |               |              |                  |              |              |                  |              |
# Row 92: 00 00 00 - Procurement and Contracting Requirements
# Row 93: 01 00 00 - General Requirements
# Row 94: 02 00 00 - Existing Conditions
# Row 95: 03 00 00 - Concrete
# Row 96: 03 30 00 - Cast-in-Place Concrete
# Row 97: 04 00 00 - Masonry
# Row 98: 05 00 00 - Metals
# Row 99: 05 01 00 - Maintenance of Metals
# Row 100: 05 01 10 - Maintenance of Structural Metal Framing
# Row 101: 05 01 20 - Maintenance of Metal Joists
# Row 102: 05 01 30 - Maintenance of Metal Decking
# Row 103: 05 01 40 - Maintenance of Cold-Formed Metal Framing
# Row 104: 05 01 50 - Maintenance of Metal Fabrications
# Row 105: 05 01 70 - Maintenance of Decorative Metal
# Row 106: 05 05 00 - Common Work Results for Metals
# Row 107: 05 05 13 - Shop-Applied Coatings for Metal
# Row 108: 05 05 23 - Metal Fastenings
# Row 109: 05 05 53 - Security Metal Fastenings
# Row 110: 05 06 00 - Schedules for Metals
# Row 111: 05 06 10 - Schedules for Structural Metal Framing
# Row 112: 05 06 20 - Schedules for Metal Joists
# Row 113: 05 06 30 - Schedules for Metal Decking
# Row 114: 05 06 40 - Schedules for Cold-Formed Metal Framing
# Row 115: 05 06 50 - Schedules for Metal Fabrications
# Row 116: 05 06 70 - Schedules for Decorative Metal
# Row 117: 05 08 00 - Commissioning of Metals
# Row 118: 05 10 00 - Structural Metal Framing
# Row 119: 05 12 00 - Structural Steel Framing
# Row 120: 05 12 13 - Architecturally-Exposed Structural Steel Framing
# Row 121: 05 12 16 - Fabricated Fireproofed Steel Columns
# Row 122: 05 12 23 - Structural Steel for Buildings
# Row 123: 05 12 33 - Structural Steel for Bridges
# Row 124: 05 13 00 - Structural Stainless-Steel Framing
# Row 125: 05 14 00 - Structural Aluminum Framing
# Row 126: 05 14 13 - Architecturally-Exposed Structural Aluminum Framing
# Row 127: 05 15 00 - Wire Rope Assemblies
# Row 128: 05 15 13 - Aluminum Wire Rope Assemblies
# Row 129: 05 15 16 - Steel Wire Rope Assemblies
# Row 130: 05 15 19 - Stainless-Steel Wire Rope Assemblies
# Row 131: 05 16 00 - Structural Cabling
# Row 132: 05 16 33 - Bridge Cabling
# Row 133: 05 20 00 - Metal Joists
# Row 134: 05 21 00 - Steel Joist Framing
# Row 135: 05 21 13 - Deep Longspan Steel Joist Framing
# Row 136: 05 21 16 - Longspan Steel Joist Framing
# Row 137: 05 21 19 - Open Web Steel Joist Framing
# Row 138: 05 21 23 - Steel Joist Girder Framing
# Row 139: 05 25 00 - Aluminum Joist Framing
# Row 140: 05 30 00 - Metal Decking
# Row 141: 05 31 00 - Steel Decking
# Row 142: 05 31 13 - Steel Floor Decking
# Row 143: 05 31 23 - Steel Roof Decking
# Row 144: 05 31 33 - Steel Form Decking
# Row 145: 05 33 00 - Aluminum Decking
# Row 146: 05 33 13 - Aluminum Floor Decking
# Row 147: 05 33 23 - Aluminum Roof Decking
# Row 148: 05 34 00 - Acoustical Metal Decking
# Row 149: 05 35 00 - Raceway Decking Assemblies
# Row 150: 05 36 00 - Composite Metal Decking
# Row 151: 05 36 13 - Composite Steel Plate and Elastomer Decking
# Row 152: 05 40 00 - Cold-Formed Metal Framing
# Row 153: 05 41 00 - Structural Metal Stud Framing
# Row 154: 05 42 00 - Cold-Formed Metal Joist Framing
# Row 155: 05 42 13 - Cold-Formed Metal Floor Joist Framing
# Row 156: 05 42 23 - Cold-Formed Metal Roof Joist Framing
# Row 157: 05 43 00 - Slotted Channel Framing
# Row 158: 05 44 00 - Cold-Formed Metal Trusses
# Row 159: 05 45 00 - Metal Support Assemblies
# Row 160: 05 45 13 - Mechanical Metal Supports
# Row 161: 05 45 16 - Electrical Metal Supports
# Row 162: 05 45 19 - Communications Metal Supports
# Row 163: 05 45 23 - Healthcare Metal Supports
# Row 164: 05 50 00 - Metal Fabrications
# Row 165: 05 51 00 - Metal Stairs
# Row 166: 05 51 13 - Metal Pan Stairs
# Row 167: 05 51 16 - Metal Floor Plate Stairs
# Row 168: 05 51 19 - Metal Grating Stairs
# Row 169: 05 51 23 - Metal Fire Escapes
# Row 170: 05 51 33 - Metal Ladders
# Row 171: 05 51 36 - Catwalks
# Row 172: 05 52 00 - Metal Railings
# Row 173: 05 52 13 - Pipe and Tube Railings
# Row 174: 05 53 00 - Metal Gratings
# Row 175: 05 54 00 - Metal Floor Plates
# Row 176: 05 55 00 - Metal Stair Treads and Nosings
# Row 177: 05 55 13 - Metal Stair Treads
# Row 178: 05 55 16 - Metal Stair Nosings
# Row 179: 05 56 00 - Metal Castings
# Row 180: 05 58 00 - Formed Metal Fabrications
# Row 181: 05 58 13 - Column Covers
# Row 182: 05 58 16 - Formed Metal Enclosures
# Row 183: 05 58 19 - Heating/Cooling Unit Covers
# Row 184: 05 59 00 - Metal Specialties
# Row 185: 05 59 63 - Detention Enclosures
# Row 186: 05 70 00 - Decorative Metal
# Row 187: 05 71 00 - Decorative Metal Stairs
# Row 188: 05 71 13 - Fabricated Metal Spiral Stairs
# Row 189: 05 73 00 - Decorative Metal Railings
# Row 190: 05 73 13 - Glazed Decorative Metal Railings
# Row 191: 05 73 16 - Wire Rope Decorative Metal Railings
# Row 192: 05 74 00 - Decorative Metal Castings
# Row 193: 05 75 00 - Decorative Formed Metal
# Row 194: 05 76 00 - Decorative Forged Metal
# Row 195: 06 00 00 - Wood, Plastics, and Composites
# Row 196: 07 00 00 - Thermal and Moisture Protection
# Row 197: 08 00 00 - Openings
# Row 198: 09 00 00 - Finishes
# Row 199: 10 00 00 - Specialties
# Row 200: 11 00 00 - Equipment
# Row 201: 12 00 00 - Furnishings
# Row 202: 13 00 00 - Special Construction
# Row 203: 14 00 00 - Conveying Equipment
# Row 204: 21 00 00 - Fire Suppression
# Row 205: 22 00 00 - Plumbing
# Row 206: 23 00 00 - Heating, Ventilating, and Air-Conditioning (HVAC)
# Row 207: 25 00 00 - Integrated Automation
# Row 208: 26 00 00 - Electrical
# Row 209: 26 24 14 - _
# Row 210: 27 00 00 - Communications
# Row 211: 28 00 00 - Electronic Safety and Security
# Row 212: 31 00 00 - Earthwork
# Row 213: 32 00 00 - Exterior Improvements
# Row 214: 33 00 00 - Utilities
# Row 215: 34 00 00 - Transportation
# Row 216: 35 00 00 - Waterway and Marine Construction
# Row 217: 40 00 00 - Process Integration
# Row 218: 40 05 15 - _
# Row 219: 41 00 00 - Material Processing and Handling Equipment
# Row 220: 42 00 00 - Process Heating, Cooling, and Drying Equipment
# Row 221: 43 00 00 - Process Gas and Liquid Handling, Purification, and Storage Equipment
# Row 222: 44 00 00 - Pollution Control Equipment
# Row 223: 45 00 00 - Industry-Specific Manufacturing Equipment
# Row 224: 48 00 00 - Electrical Power Generation
# Task exception was never retrieved
# future: <Task finished name='Task-157' coro=<Channel.send() done, defined at /home/pdcur/samsung-project/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py:61> exception=Exception('Channel.send: Connection closed while reading from the driver')>
# Traceback (most recent call last):
#   File "/home/pdcur/samsung-project/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py", line 69, in send
#     return await self._connection.wrap_api_call(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/pdcur/samsung-project/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py", line 559, in wrap_api_call
#     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
# Exception: Channel.send: Connection closed while reading from the driver
# Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed\nCall log:\n  - waiting for locator("iframe[name=\\"fraMenuContent\\"]").content_frame.locator("#ucSearchPanel_ctl38_txtCSICodeLookupInput")\n    - locator resolved to <textarea rows="2" readonly cols="20" csicodelookup="" data-field-value="SpecSection" class="Text CSICodeLookupInput" id="ucSearchPanel_ctl38_txtCSICodeLookupInput" name="ucSearchPanel$ctl38$txtCSICodeLookupInput"></textarea>\n    - fill("05 12 00 - Structural Steel Framing")\n  - attempting fill action\n    2 × waiting for element to be visible, enabled and editable\n      - element is not editable\n    - retrying fill action\n    - waiting 20ms\n    2 × waiting for element to be visible, enabled and editable\n      - element is not editable\n    - retrying fill action\n      - waiting 100ms\n    19 × waiting for element to be visible, enabled and editable\n       - element is not editable\n     - retrying fill action\n       - waiting 500ms\n')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
# Call log:
#   - waiting for locator("iframe[name=\"fraMenuContent\"]").content_frame.locator("#ucSearchPanel_ctl38_txtCSICodeLookupInput")
#     - locator resolved to <textarea rows="2" readonly cols="20" csicodelookup="" data-field-value="SpecSection" class="Text CSICodeLookupInput" id="ucSearchPanel_ctl38_txtCSICodeLookupInput" name="ucSearchPanel$ctl38$txtCSICodeLookupInput"></textarea>
#     - fill("05 12 00 - Structural Steel Framing")
#   - attempting fill action
#     2 × waiting for element to be visible, enabled and editable
#       - element is not editable
#     - retrying fill action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and editable
#       - element is not editable
#     - retrying fill action
#       - waiting 100ms
#     19 × waiting for element to be visible, enabled and editable
#        - element is not editable
#      - retrying fill action
#        - waiting 500ms
#
# Future exception was never retrieved
# future: <Future finished exception=Exception('Connection closed while reading from the driver')>
# Exception: Connection closed while reading from the driver
# /usr/lib/python3.12/ast.py:52: RuntimeWarning: coroutine 'Locator.click' was never awaited
#   return compile(source, filename, mode, flags,
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[61], line 23
#      20 processed = count
#      22 # Scroll to the last row to trigger loading more rows
# ---> 23 await rows.last.scroll_into_view_if_needed()
#      24 await frame.wait_for_timeout(2000)  # Wait for new rows to load
#      26 # Check if more rows were loaded
#
# File ~/samsung-project/.venv/lib/python3.12/site-packages/playwright/async_api/_generated.py:17489, in Locator.scroll_into_view_if_needed(self, timeout)
#   17470 async def scroll_into_view_if_needed(
#   17471     self, *, timeout: typing.Optional[float] = None
#   17472 ) -> None:
#   17473     """Locator.scroll_into_view_if_needed
#   17474
#   17475     This method waits for [actionability](https://playwright.dev/python/docs/actionability) checks, then tries to scroll element into view, unless
#    (...)  17485         be changed by using the `browser_context.set_default_timeout()` or `page.set_default_timeout()` methods.
#   17486     """
#   17488     return mapping.from_maybe_impl(
# > 17489         await self._impl_obj.scroll_into_view_if_needed(timeout=timeout)
#   17490     )
#
# File ~/samsung-project/.venv/lib/python3.12/site-packages/playwright/_impl/_locator.py:581, in Locator.scroll_into_view_if_needed(self, timeout)
#     577 async def scroll_into_view_if_needed(
#     578     self,
#     579     timeout: float = None,
#     580 ) -> None:
# --> 581     return await self._with_element(
#     582         lambda h, timeout: h.scroll_into_view_if_needed(timeout=timeout),
#     583         timeout,
#     584     )
#
# File ~/samsung-project/.venv/lib/python3.12/site-packages/playwright/_impl/_locator.py:117, in Locator._with_element(self, task, timeout)
#     115     raise Error(f"Could not resolve {self._selector} to DOM Element")
#     116 try:
# --> 117     return await task(
#     118         handle,
#     119         (deadline - monotonic_time()) if deadline else 0,
#     120     )
#     121 finally:
#     122     await handle.dispose()
#
# File ~/samsung-project/.venv/lib/python3.12/site-packages/playwright/_impl/_element_handle.py:113, in ElementHandle.scroll_into_view_if_needed(self, timeout)
#     112 async def scroll_into_view_if_needed(self, timeout: float = None) -> None:
# --> 113     await self._channel.send(
#     114         "scrollIntoViewIfNeeded", self._frame._timeout, locals_to_params(locals())
#     115     )
#
# File ~/samsung-project/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)     67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File ~/samsung-project/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py:559, in Connection.wrap_api_call(self, cb, is_internal, title)
#     557     return await cb()
#     558 except Exception as error:
# --> 559     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     560 finally:
#     561     self._api_zone.set(None)
#
# TimeoutError: Locator.scroll_into_view_if_needed: Timeout 29985ms exceeded.
# Call log:
#   - attempting scroll into view action
#     2 × waiting for element to be stable
#       - element is not visible
#     - retrying scroll into view action
#     - waiting 20ms
#     2 × waiting for element to be stable
#       - element is not visible
#     - retrying scroll into view action
#       - waiting 100ms
#     58 × waiting for element to be stable
#        - element is not visible
#      - retrying scroll into view action
#        - waiting 500ms

# %%
# Take a screenshot
await page.screenshot(path="screenshot.png")
print("Screenshot saved to screenshot.png")

# %% [markdown]
# ## Cleanup

# %%
# Cleanup - run when done
await browser.close()
await pw.stop()
print("Browser closed")

# %%
# Optional: Delete saved session (to force fresh login next time)
if storage_path.exists():
    storage_path.unlink()
    print("Session deleted")
else:
    print("No session to delete")
